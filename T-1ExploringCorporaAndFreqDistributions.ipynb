# %%
import nltk

nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all-corpora
# ...
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
# ...

# %% [markdown]
# ## Task 2: Exploring Brown Corpus

# %%
from nltk.corpus import brown 

brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
brown.words(categories = 'adventure')[:15]
# Out:
# ['Dan',
#  'Morgan',
#  'told',
#  'himself',
#  'he',
#  'would',
#  'forget',
#  'Ann',
#  'Turner',
#  '.',
#  'He',
#  'was',
#  'well',
#  'rid',
#  'of']

# %% [markdown]
# # Task 3: Exploring Inaugral Corpus

# %%
from nltk.corpus import inaugural

inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
inaugural.words(fileids = '2013-Obama.txt')[:50]
# Out:
# ['Thank',
#  'you',
#  '.',
#  'Thank',
#  'you',
#  'so',
#  'much',
#  '.',
#  'Vice',
#  'President',
#  'Biden',
#  ',',
#  'Mr',
#  '.',
#  'Chief',
#  'Justice',
#  ',',
#  'Members',
#  'of',
#  'the',
#  'United',
#  'States',
#  'Congress',
#  ',',
#  'distinguished',
#  'guests',
#  ',',
#  'and',
#  'fellow',
#  'citizens',
#  ':',
#  'Each',
#  'time',
#  'we',
#  'gather',
#  'to',
#  'inaugurate',
#  'a',
#  'President',
#  'we',
#  'bear',
#  'witness',
#  'to',
#  'the',
#  'enduring',
#  'strength',
#  'of',
#  'our',
#  'Constitution',
#  '.']

# %% [markdown]
# # Task 4: Exploring Webtext corpus (Homework)

# %%
from nltk.corpus import webtext

webtext.words(fileids = 'wine.txt')[:20]
# Out:
# ['Lovely',
#  'delicate',
#  ',',
#  'fragrant',
#  'Rhone',
#  'wine',
#  '.',
#  'Polished',
#  'leather',
#  'and',
#  'strawberries',
#  '.',
#  'Perhaps',
#  'a',
#  'bit',
#  'dilute',
#  ',',
#  'but',
#  'good',
#  'for']

# %% [markdown]
# # Task 5: Frequency Distribution

# %%
text = webtext.words(fileids = 'wine.txt')

fd = nltk.FreqDist(text)
fd
# Out:
# FreqDist({'Lovely': 85,
#           'delicate': 9,
#           ',': 1536,
#           'fragrant': 25,
#           'Rhone': 6,
#           'wine': 229,
#           '.': 2772,
#           'Polished': 1,
#           'leather': 3,
#           'and': 787,
#           'strawberries': 4,
#           'Perhaps': 18,
#           'a': 821,
#           'bit': 217,
#           'dilute': 8,
#           'but': 474,
#           'good': 250,
#           'for': 145,
#           'drinking': 74,
#           'now': 64,
#           '***': 498,
#           'Liquorice': 4,
#           'cherry': 19,
#           'fruit': 296,
#           'Simple': 8,
#           'coarse': 12,
#           'at': 121,
#           'the': 706,
#           'finish': 77,
#           '**': 162,
#           'Thin': 2,
#           'completely': 13,
#           'uninspiring': 1,
#           '*': 43,
#           'Rough': 1,
#           'No': 22,
#           'Stars': 11,
#           'Big': 10,
#           'fat': 6,
# ...

# %% [markdown]
# #Task 6: Conditional Frequency Distribution

# %%
from nltk.probability import ConditionalFreqDist

cfd = ConditionalFreqDist((len(word), word) for word in text)

# %%
cfd[5] #words with five character length
# Out:
# FreqDist({'**(*)': 57,
#           '*****': 53,
#           '1990s': 1,
#           'About': 1,
#           'Added': 1,
#           'After': 1,
#           'Again': 7,
#           'Alive': 1,
#           'Apple': 2,
#           'Asian': 1,
#           'Auxey': 1,
#           'Bages': 2,
#           'Baked': 5,
#           'Being': 2,
#           'Berry': 1,
#           'Bisol': 1,
#           'Black': 2,
#           'Blanc': 2,
#           'Blows': 1,
#           'Bolly': 1,
#           'Breed': 1,
#           'Brion': 1,
#           'Brown': 1,
#           'Brune': 1,
#           'Burnt': 3,
#           'Cases': 1,
#           'Chave': 1,
#           'Chewy': 1,
#           'Cigar': 1,
#           'Class': 1,
#           'Clean': 9,
#           'Clear': 2,
#           'Combe': 1,
#           'Cotes': 1,
#           'Cough': 2,
#           'Could': 10,
#           'Cream': 1,
#           'Cuvee': 1,
#           'Dairy': 1,
#           'Dense': 3,
#           'Deutz': 1,
# ...

# %% [markdown]
# #Task 7: Freq distribution and Conditional Freq distribution for the innaugural speech of a US President (Homework)

# %%
Lincoln = '1865-Lincoln.txt'

Lincoln_speech = inaugural.words(fileids=Lincoln)

Lincoln_speech_length = len([word for word in Lincoln_speech if word not in "',./-?!"])
print(Lincoln_speech_length)

Lincoln_fd = nltk.FreqDist([word for word in Lincoln_speech if word not in "',./-?!"])
Lincoln_fd.most_common(50)
# Out:
# 712
# [('the', 55),
#  ('to', 26),
#  ('and', 24),
#  ('of', 22),
#  ('it', 12),
#  ('war', 12),
#  ('that', 11),
#  ('for', 9),
#  ('in', 9),
#  ('which', 9),
#  ('be', 8),
#  ('all', 8),
#  ('this', 7),
#  ('a', 7),
#  ('is', 6),
#  ('by', 6),
#  ('with', 6),
#  ('God', 6),
#  ('we', 6),
#  ('was', 5),
#  ('as', 5),
#  ('but', 5),
#  ('shall', 5),
#  ('than', 4),
#  ('years', 4),
#  ('Union', 4),
#  ('let', 4),
#  ('not', 4),
#  ('do', 4),
#  ('s', 4),
#  ('an', 3),
#  ('nation', 3),
#  ('The', 3),
#  ('were', 3),
#  ('from', 3),
#  ('would', 3),
#  ('other', 3),
#  ('interest', 3),
#  ('right', 3),
#  ('has', 3),
#  ('His', 3),
#  ('may', 3),
#  ('us', 3),
#  ('offenses', 3),
#  ('must', 3),
#  ('those', 3),
#  ('there', 2),
#  ('less', 2),
#  ('occasion', 2),
#  ('address', 2)]

# %%
Obama = '2013-Obama.txt'

Obama_speech = inaugural.words(fileids=Obama)
Obama_speech_length = len([word for word in Obama_speech if word not in "',./-?!"])
print(Obama_speech_length)

Obama_fd = nltk.FreqDist([word for word in Obama_speech if word not in "',./-?!"])
Obama_fd.most_common(50)
# Out:
# 2157
# [('the', 100),
#  ('and', 85),
#  ('of', 69),
#  ('our', 69),
#  ('to', 66),
#  ('that', 51),
#  ('we', 46),
#  ('a', 36),
#  ('is', 25),
#  ('We', 23),
#  ('not', 23),
#  ('for', 22),
#  ('us', 21),
#  ('in', 21),
#  ('are', 21),
#  ('will', 20),
#  ('must', 17),
#  (';', 14),
#  ('or', 13),
#  ('\x80\x94', 13),
#  ('this', 12),
#  ('all', 12),
#  ('with', 12),
#  ('as', 12),
#  ('by', 11),
#  ('those', 11),
#  ('people', 11),
#  ('s', 11),
#  ('these', 10),
#  ('be', 10),
#  ('from', 10),
#  ('time', 9),
#  ('it', 9),
#  ('have', 9),
#  ('do', 8),
#  ('America', 8),
#  ('who', 8),
#  ('what', 7),
#  ('more', 7),
#  ('they', 7),
#  ('on', 7),
#  ('when', 7),
#  ('can', 7),
#  ('Our', 7),
#  ('country', 7),
#  ('make', 7),
#  ('every', 7),
#  ('but', 7),
#  ('so', 6),
#  ('citizens', 6)]

# %% [markdown]
# Lincoln in 1865 had a much **shorter** speech than Obama in 2013. This could possibly be due to the lesser number of predecessors hence lesser expectations from Lincoln and even the complexity of those expectations was less.
#
# Another point to be noted is Lincoln's religious focus when starting his speech in comparsion to Obama's social introduction. This could also be a result of the society's views and preferences.
